# %%
import tensorflow as tf
import strawberryfields as sf
import numpy as np
import matplotlib.pyplot as plt

from strawberryfields import ops

from qmlt.tf import CircuitLearner
from qmlt.tf.helpers import make_param

from sklearn.utils import shuffle
from sklearn.datasets import load_digits
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
tf.set_random_seed(0)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14232022563414604654
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7433623962
# locality {
#   bus_id: 1
# }
# incarnation: 2301335516472134331
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:65:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# ### Preparing dataset
#
# We install a data from

# %%
 def make_matrixes_4x4(x, axs_scale):  # TODO

        """
            идем матрицей 4х4 с шагом 1,
            тогда из мтарицы 8х8 получаем 5х5
        """
        output = []
        for i in range(0, axs_scale-3, 1):  # x
            for j in range(0, axs_scale-3, 1):  # y
                matrix = [x[i][j], x[i][j + 1], x[i][j + 2], x[i][j + 3],
                         x[i + 1][j], x[i + 1][j + 1], x[i + 1][j + 2], x[i + 1][j + 3],
                         x[i + 2][j], x[i + 2][j + 1], x[i + 2][j + 2], x[i + 2][j + 3],
                         x[i + 3][j], x[i + 3][j + 1], x[i + 3][j + 2], x[i + 3][j + 3]]
                
                output.append(matrix) 
        return output

# %% [markdown]
# **code to visualize samples from the dataset**

# %%
def draw_samples(samples, samples_number: int) -> None:
    """
    Visualize an ordered amount of randomly chosen samples from a given dataset.
    :param dataset: A Dataset from which to take samples to visualize
    :param samples_number: A number of samples to visualize
    """

    if samples_number % 4 == 0:
        rows = samples_number//4
    else:
        rows = samples_number // 4 + 1

    if samples_number > 4:
        fig, axs = plt.subplots(nrows=rows, ncols=4)
        for i in range(samples_number):
            index = np.random.randint(len(samples))
            # print(index)
            # print(dataset.trainX.shape)
            axs[i // 4, i % 4].imshow(samples[index].reshape([8, 8]))
    else:
        fig, axs = plt.subplots(nrows=rows, ncols=4)
        for i in range(samples_number):
            index = np.random.randint(len(samples))
            # print(dataset.trainX[index].shape)
            axs[i % 4].imshow(samples[index].reshape([8, 8]))
            
    plt.show()

#     plt.savefig('Mnist/CNN/Digits.png')

# %%
def create_dataset(split=0.1):
    digits = load_digits()
    
    x = np.array(digits.data) / 255.0
    y = np.array(digits.target)
    
    x, y = shuffle(x, y, random_state=7)

    sep = round(len(x)*split)

    train_x, train_y = x[sep:], y[sep:]
    test_x, test_y = x[:sep], y[:sep]
    
    draw_samples(test_x, 8)

    return train_x, train_y, test_x, test_y

# %%
def create_dataset_binary(class0: int, class1=None, split=0.1):
    # загружаем датасет
    digits = load_digits()

    x = np.array(digits.data) / 255.0
    y = np.array(digits.target)

    x0, y0 = x[y == class0], y[y == class0]
    y0 = np.zeros(len(y0))

    if class1 is not None:
        x1, y1 = x[y == class1], y[y == class1]
        y1 = np.ones(len(y1))
    else:
        x1, y1 = x[y != class0], y[y != class0]
        y1 = np.zeros(len(y1))

    x, y = np.vstack((x0, x1)), np.hstack([y0, y1])
    x, y = shuffle(x, y, random_state=7)

    sep = round(len(y) * split)  # default ~10% for a test

    train_x, train_y = x[sep:], y[sep:]
    test_x, test_y = x[:sep], y[:sep]
    
    draw_samples(test_x, 8)

    return train_x, train_y, test_x, test_y

# %% [markdown]
# ## Quantum Neural Network Model

# %%
wires = 8
params_num = 48 + 30 + 34


def myloss(circuit_output, targets):
    return tf.losses.mean_squared_error(labels=circuit_output, predictions=targets)


def outputs_to_predictions(outpt):
    return tf.round(outpt)

def circuit(X):

#     params = [make_param(name='phi'+str(i), constant=.5, monitor=True, regularize=False) for i in range(20)]

    def shaper(x):
        """
        x - a single picture
        :param x: an array of pixels
        :return: shape and reshaped array of pixels
        """
        print(x)

        if x.shape[0] == 64:
            return 8, tf.reshape(x, [8, 8])
        elif x.shape[0] == 36:
            return 6, tf.reshape(x, [6, 6])
        elif x.shape[0] == 35:
            return 5, tf.reshape(x, [5, 5])
        elif x.shape[0] == 16:
            return 4, tf.reshape(x, [4, 4])
        elif x.shape[0] == 9:
            return 3, tf.reshape(x, [3, 3])
        elif x.shape[0] == 4:
            return 2, tf.reshape(x, [2, 2])

    def conv_4x4_layer(x, params, global_delta):
        """
        54 parameters
        :param x: input data with shape (4,)
        :param delta: parameters shift for the current layer
        :return: bosons amount in the 0's qumode.
        """
        
        eng, q = sf.Engine(4)
        
        quater_pi = tf.constant(np.pi / 4, dtype=tf.double)
        
        def layer(delta):
            ops.BSgate(quater_pi, 0.0) | (q[0], q[1])
            ops.BSgate(quater_pi, 0.0) | (q[2], q[3])
#             ops.BSgate(quater_pi, 0) | (q[4], q[5])
#             ops.BSgate(quater_pi, 0) | (q[6], q[7])
            ops.Rgate(params[0 + delta]) | q[0]
            ops.Rgate(params[1 + delta]) | q[1]
            ops.Rgate(params[2 + delta]) | q[2]
            ops.Rgate(params[3 + delta]) | q[3]
            ops.BSgate(quater_pi, 0.0) | (q[1], q[2])
            ops.BSgate(quater_pi, 0.0) | (q[0], q[3])
            ops.Rgate(params[4 + delta]) | q[0]
            ops.Rgate(params[5 + delta]) | q[1]
            ops.Rgate(params[6 + delta]) | q[2]
            ops.Rgate(params[7 + delta]) | q[3]
            ops.Dgate(params[8 + delta]) | q[0]
            ops.Dgate(params[9 + delta]) | q[1]
            ops.Pgate(params[10 + delta]) | q[2]
            ops.Pgate(params[11 + delta]) | q[3]

        with eng:
            for d in range(4):
                for j in range(4):
                    ops.Sgate(1.5, x[:, j + 4 * d]) | q[j]
                
                layer(global_delta + d * 12)

        num_inputs = x.get_shape().as_list()[0]
        state = eng.run('tf', cutoff_dim=7, eval=False, batch_size=num_inputs)
        
        modes = 4*[0]
        modes[0] = 2
        p0 = state.fock_prob(modes)
        modes[0] = 0
        modes[1] = 2
        p1 = state.fock_prob(modes)

        normalization = p0 + p1 + 1e-10  # + p2
        output = p0 / normalization
        return tf.cast(output, dtype=tf.float64)
    
    def conv_3x3_layer(x, params, global_delta):
        """
        54 parameters
        :param x: input data with shape (4,)
        :param delta: parameters shift for the current layer
        :return: bosons amount in the 0's qumode.
        """
        
        eng, q = sf.Engine(3)
        
        quater_pi = tf.constant(np.pi / 4, dtype=tf.double)
        
        def layer(delta):
            ops.BSgate(quater_pi, 0.0) | (q[0], q[1])
            ops.BSgate(quater_pi, 0.0) | (q[2], q[1])
            ops.Rgate(params[0 + delta]) | q[0]
            ops.Rgate(params[1 + delta]) | q[1]
            ops.Rgate(params[2 + delta]) | q[2]
            ops.BSgate(quater_pi, 0.0) | (q[1], q[2])
            ops.BSgate(quater_pi, 0.0) | (q[0], q[2])
            ops.Rgate(params[3 + delta]) | q[0]
            ops.Rgate(params[4 + delta]) | q[1]
            ops.Rgate(params[5 + delta]) | q[2]
            ops.Dgate(params[6 + delta]) | q[0]
            ops.Dgate(params[7 + delta]) | q[1]
            ops.Pgate(params[8 + delta]) | q[0]
            ops.Pgate(params[9 + delta]) | q[1]

        with eng:
            for d in range(3):
                for j in range(3):
                    ops.Sgate(1.5, x[:, j + 3 * d]) | q[j]
                
                layer(global_delta + d * 10)

        num_inputs = x.get_shape().as_list()[0]
        state = eng.run('tf', cutoff_dim=7, eval=False, batch_size=num_inputs)
        
        modes = 3*[0]
        modes[0] = 2
        p0 = state.fock_prob(modes)
        modes[0] = 0
        modes[1] = 2
        p1 = state.fock_prob(modes)

        normalization = p0 + p1 + 1e-10  # + p2
        output = p0 / normalization
        return tf.cast(output, dtype=tf.float64)


    def full_con_layer(x, delta, params):

        eng, q = sf.Engine(3)
        
        quater_pi = tf.constant(np.pi / 4)            

        with eng:
            for k in range(3):
                for j in range(3):
                    ops.Sgate(1.5, x[:, j+3*k]) | q[j]
                    
                ops.BSgate(quater_pi, 0) | (q[0], q[1])
                ops.BSgate(quater_pi, 0) | (q[2], q[1])
                
                for j in range(3):
                    ops.Rgate(params[j + 6 * k + delta])
                    
                ops.BSgate(quater_pi, 0) | (q[0], q[2])
                ops.BSgate(quater_pi, 0) | (q[1], q[0])
                    
                for j in range(3):
                    ops.Rgate(params[j + 3 * (2 * k + 1)  + delta])
            
            ops.Dgate(params[18 + delta]) | q[0]
            ops.Dgate(params[19 + delta]) | q[1]
            ops.Dgate(params[20 + delta]) | q[2]
            ops.Pgate(params[21 + delta]) | q[0]
            ops.Pgate(params[22 + delta]) | q[1]
            ops.Pgate(params[23 + delta]) | q[2]

        num_inputs = x.get_shape().as_list()[0]
        state = eng.run('tf', cutoff_dim=7, eval=False, batch_size=num_inputs)


        modes = 3*[0]
        modes[0] = 2
        p0 = state.fock_prob(modes)
        modes[0] = 0
        modes[1] = 2
        p1 = state.fock_prob(modes)

        normalization = p0 + p1 + 1e-10  # + p2
        output = p0 / normalization  # , p1 / normalization]  # , p2 / normalization]

        return output
    
    def make_matrixes_3x3(x, axs_scale):  # TODO

        """
            идем матрицей 3х3 с шагом 1,
            тогда из мтарицы 5х5 получаем 3х3
        """
        output = []
        for i in range(0, axs_scale-2, 1):  # x
            for j in range(0, axs_scale-2, 1):  # y
                matrix = [x[i][j], x[i][j + 1], x[i][j + 2],
                         x[i + 1][j], x[i + 1][j + 1], x[i + 1][j + 2],
                         x[i + 2][j], x[i + 2][j + 1], x[i + 2][j + 2]]
                
                output.append(matrix) 
        return output

    def single_circuit(input_x):  
        
        params = [make_param(name='phi'+str(i), constant=.5, monitor=True, regularize=False) for i in range(params_num)]
        
        _x = tf.map_fn(lambda x: conv_4x4_layer(x, params, 0), input_x)  # нужно сделать так, чтобы передавать кол-во сверток
#         _x = tf.reshape(_x,)
        _x = tf.reshape(_x, [_x.shape[0], 5, 5])
#         _x = tf.map_fn(lambda x: make_matrixes_3x3(tf.reshape(x, [x.shape[0], 5, 5]), 5), _x)
        _x = tf.map_fn(lambda x: conv_3x3_layer(x, params, 48), input_x)
#         _x = conv_4x4_layer(input_x, params)
        output = full_con_layer(_x, 78, params)
        return output

    return single_circuit(X)

# %% [markdown]
# ## Start of the learning

# %%
train_x, train_y, test_x, test_y = create_dataset_binary(class0=1, class1=9)

# %%
# reshape input as image
train_x = np.reshape(train_x, [len(train_y), 8, 8])
print('train_x shape', train_x.shape)
test_x = np.reshape(test_x, [len(test_y), 8, 8])
print('test_x shape', test_x.shape)
# Out:
# train_x shape (326, 8, 8)
# test_x shape (36, 8, 8)

# %%
# we will make matrixes now and feed them into QCNN
train_x = np.array([make_matrixes_4x4(x, 8) for x in train_x])
print(train_x.shape)
test_x = np.array([make_matrixes_4x4(x, 8) for x in test_x])
print(test_x.shape)
# Out:
# (326, 25, 16)
# (36, 25, 16)

# %%
lr = 0.0015
# steps = [10, 30, 50, 70, 100, 200, 300] #, 500, 700, 1000]
# steps = [10, 20, 30, 40, 50, 60, 70, 80, 90]
steps = [i for i in range(10, 810, 50)]
# steps = np.arange(500, 501, 10)
print(steps)
batch_size = 2

test_acc, test_loss = [], []
train_acc, train_loss = [], []

hyperparams = {'circuit': circuit,
               'task': 'supervised',
               'loss': myloss,
               'optimizer': 'Adam',
               'init_learning_rate': lr,
               'log_every': 1,
               'warm_start': False}

for step in steps:

    learner = CircuitLearner(hyperparams=hyperparams)

    learner.train_circuit(X=train_x, Y=train_y, steps=step, batch_size=batch_size)

    test_score = learner.score_circuit(X=test_x, Y=test_y,
                                       outputs_to_predictions=outputs_to_predictions)

    test_acc.append(test_score['accuracy'])
    test_loss.append(test_score['loss'])

    train_score = learner.score_circuit(X=train_x, Y=train_y,
                                       outputs_to_predictions=outputs_to_predictions)

    train_acc.append(train_score['accuracy'])
    train_loss.append(train_score['loss'])
# Out:
# [10, 60, 110, 160, 210, 260, 310, 360, 410, 460, 510, 560, 610, 660, 710, 760]
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - None (default value)
# circuit - User defined function.
# decay - 0.0 (default value)
# init_learning_rate - 0.0015
# log_every - 1
# loss - User defined function.
# model_dir - None (default value)
# optimizer - Adam
# outputs_to_predictions - None (default value)
# plot_every - 1 (default value)
# print_log - True (default value)
# regularization_strength - 0.1 (default value)
# regularizer - No regularizer provided.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'logsAUTO', '_service': None, '_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_is_chief': True, '_task_id': 0, '_save_summary_steps': 100, '_evaluation_master': '', '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_session_config': None, '_keep_checkpoint_max': 5, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7feadbf32ef0>, '_save_checkpoints_secs': 600, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_global_id_in_cluster': 0}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0
# INFO:tensorflow:Cost = 0.26188615, Step = 6, Regularization = 0.0, Loss = 0.26188615 (0.290 sec)
# INFO:tensorflow:Cost = 0.26177913, Step = 7, Regularization = 0.0, Loss = 0.26177913 (0.281 sec)
# INFO:tensorflow:Cost = 0.36878628, Step = 8, Regularization = 0.0, Loss = 0.36878628 (0.286 sec)
# INFO:tensorflow:Cost = 0.25145414, Step = 9, Regularization = 0.0, Loss = 0.25145414 (0.291 sec)
# INFO:tensorflow:Cost = 0.25155523, Step = 10, Regularization = 0.0, Loss = 0.25155523 (0.262 sec)
# INFO:tensorflow:Cost = 0.2544009, Step = 11, Regularization = 0.0, Loss = 0.2544009 (0.291 sec)
# INFO:tensorflow:Cost = 0.31736022, Step = 12, Regularization = 0.0, Loss = 0.31736022 (0.283 sec)
# INFO:tensorflow:Cost = 0.20048493, Step = 13, Regularization = 0.0, Loss = 0.20048493 (0.276 sec)
# INFO:tensorflow:Cost = 0.2860021, Step = 14, Regularization = 0.0, Loss = 0.2860021 (0.287 sec)
# INFO:tensorflow:Cost = 0.24825338, Step = 15, Regularization = 0.0, Loss = 0.24825338 (0.284 sec)
# INFO:tensorflow:Cost = 0.22199914, Step = 16, Regularization = 0.0, Loss = 0.22199914 (0.271 sec)
# INFO:tensorflow:Cost = 0.23214504, Step = 17, Regularization = 0.0, Loss = 0.23214504 (0.285 sec)
# INFO:tensorflow:Cost = 0.22380495, Step = 18, Regularization = 0.0, Loss = 0.22380495 (0.288 sec)
# INFO:tensorflow:Cost = 0.25190082, Step = 19, Regularization = 0.0, Loss = 0.25190082 (0.293 sec)
# INFO:tensorflow:Cost = 0.22937718, Step = 20, Regularization = 0.0, Loss = 0.22937718 (0.295 sec)
# INFO:tensorflow:Cost = 0.22624865, Step = 21, Regularization = 0.0, Loss = 0.22624865 (0.290 sec)
# INFO:tensorflow:Cost = 0.23470101, Step = 22, Regularization = 0.0, Loss = 0.23470101 (0.268 sec)
# INFO:tensorflow:Cost = 0.22554877, Step = 23, Regularization = 0.0, Loss = 0.22554877 (0.271 sec)
# INFO:tensorflow:Cost = 0.2730704, Step = 24, Regularization = 0.0, Loss = 0.2730704 (0.273 sec)
# INFO:tensorflow:Cost = 0.2389847, Step = 25, Regularization = 0.0, Loss = 0.2389847 (0.256 sec)
# INFO:tensorflow:Cost = 0.28450155, Step = 26, Regularization = 0.0, Loss = 0.28450155 (0.277 sec)
# INFO:tensorflow:Cost = 0.20685291, Step = 27, Regularization = 0.0, Loss = 0.20685291 (0.288 sec)
# INFO:tensorflow:Cost = 0.22132388, Step = 28, Regularization = 0.0, Loss = 0.22132388 (0.280 sec)
# INFO:tensorflow:Cost = 0.20925373, Step = 29, Regularization = 0.0, Loss = 0.20925373 (0.303 sec)
# INFO:tensorflow:Cost = 0.25571546, Step = 30, Regularization = 0.0, Loss = 0.25571546 (0.274 sec)
# INFO:tensorflow:Cost = 0.1990664, Step = 31, Regularization = 0.0, Loss = 0.1990664 (0.272 sec)
# INFO:tensorflow:Cost = 0.082389876, Step = 126, Regularization = 0.0, Loss = 0.082389876 (0.282 sec)
# INFO:tensorflow:Cost = 0.05646323, Step = 127, Regularization = 0.0, Loss = 0.05646323 (0.283 sec)
# INFO:tensorflow:Cost = 0.26045644, Step = 128, Regularization = 0.0, Loss = 0.26045644 (0.287 sec)
# INFO:tensorflow:Cost = 0.05122416, Step = 129, Regularization = 0.0, Loss = 0.05122416 (0.312 sec)
# INFO:tensorflow:Cost = 0.081461586, Step = 130, Regularization = 0.0, Loss = 0.081461586 (0.291 sec)
# INFO:tensorflow:Cost = 0.28558353, Step = 131, Regularization = 0.0, Loss = 0.28558353 (0.280 sec)
# INFO:tensorflow:Cost = 0.21971281, Step = 132, Regularization = 0.0, Loss = 0.21971281 (0.270 sec)
# INFO:tensorflow:Cost = 0.21428168, Step = 133, Regularization = 0.0, Loss = 0.21428168 (0.295 sec)
# INFO:tensorflow:Cost = 0.15148395, Step = 134, Regularization = 0.0, Loss = 0.15148395 (0.279 sec)
# INFO:tensorflow:Cost = 0.1530421, Step = 135, Regularization = 0.0, Loss = 0.1530421 (0.288 sec)
# INFO:tensorflow:Cost = 0.06229632, Step = 136, Regularization = 0.0, Loss = 0.06229632 (0.254 sec)
# INFO:tensorflow:Cost = 0.24715114, Step = 137, Regularization = 0.0, Loss = 0.24715114 (0.273 sec)
# INFO:tensorflow:Cost = 0.19432653, Step = 138, Regularization = 0.0, Loss = 0.19432653 (0.283 sec)
# INFO:tensorflow:Cost = 0.236942, Step = 139, Regularization = 0.0, Loss = 0.236942 (0.289 sec)
# INFO:tensorflow:Cost = 0.2429529, Step = 140, Regularization = 0.0, Loss = 0.2429529 (0.293 sec)
# INFO:tensorflow:Cost = 0.08969873, Step = 141, Regularization = 0.0, Loss = 0.08969873 (0.289 sec)
# INFO:tensorflow:Cost = 0.14161877, Step = 142, Regularization = 0.0, Loss = 0.14161877 (0.293 sec)
# INFO:tensorflow:Cost = 0.2793374, Step = 143, Regularization = 0.0, Loss = 0.2793374 (0.265 sec)
# INFO:tensorflow:Cost = 0.3465176, Step = 144, Regularization = 0.0, Loss = 0.3465176 (0.280 sec)
# INFO:tensorflow:Cost = 0.28102353, Step = 145, Regularization = 0.0, Loss = 0.28102353 (0.294 sec)
# INFO:tensorflow:Cost = 0.16915652, Step = 146, Regularization = 0.0, Loss = 0.16915652 (0.287 sec)
# INFO:tensorflow:Cost = 0.19357273, Step = 147, Regularization = 0.0, Loss = 0.19357273 (0.289 sec)
# INFO:tensorflow:Cost = 0.23050332, Step = 148, Regularization = 0.0, Loss = 0.23050332 (0.302 sec)
# INFO:tensorflow:Cost = 0.323833, Step = 149, Regularization = 0.0, Loss = 0.323833 (0.295 sec)
# INFO:tensorflow:Cost = 0.25785828, Step = 150, Regularization = 0.0, Loss = 0.25785828 (0.287 sec)
# INFO:tensorflow:Cost = 0.130487, Step = 151, Regularization = 0.0, Loss = 0.130487 (0.312 sec)
# INFO:tensorflow:Cost = 0.2860021, Step = 14, Regularization = 0.0, Loss = 0.2860021 (0.298 sec)
# INFO:tensorflow:Cost = 0.24825338, Step = 15, Regularization = 0.0, Loss = 0.24825338 (0.286 sec)
# INFO:tensorflow:Cost = 0.22199914, Step = 16, Regularization = 0.0, Loss = 0.22199914 (0.296 sec)
# INFO:tensorflow:Cost = 0.23214504, Step = 17, Regularization = 0.0, Loss = 0.23214504 (0.287 sec)
# INFO:tensorflow:Cost = 0.22380495, Step = 18, Regularization = 0.0, Loss = 0.22380495 (0.277 sec)
# INFO:tensorflow:Cost = 0.25190082, Step = 19, Regularization = 0.0, Loss = 0.25190082 (0.303 sec)
# INFO:tensorflow:Cost = 0.22937718, Step = 20, Regularization = 0.0, Loss = 0.22937718 (0.291 sec)
# INFO:tensorflow:Cost = 0.22624865, Step = 21, Regularization = 0.0, Loss = 0.22624865 (0.296 sec)
# INFO:tensorflow:Cost = 0.23470101, Step = 22, Regularization = 0.0, Loss = 0.23470101 (0.280 sec)
# INFO:tensorflow:Cost = 0.22554877, Step = 23, Regularization = 0.0, Loss = 0.22554877 (0.279 sec)
# INFO:tensorflow:Cost = 0.2730704, Step = 24, Regularization = 0.0, Loss = 0.2730704 (0.300 sec)
# INFO:tensorflow:Cost = 0.2389847, Step = 25, Regularization = 0.0, Loss = 0.2389847 (0.284 sec)
# INFO:tensorflow:Cost = 0.28450155, Step = 26, Regularization = 0.0, Loss = 0.28450155 (0.277 sec)
# INFO:tensorflow:Cost = 0.20685291, Step = 27, Regularization = 0.0, Loss = 0.20685291 (0.298 sec)
# ...
# INFO:tensorflow:Cost = 0.07499145, Step = 333, Regularization = 0.0, Loss = 0.07499145 (0.300 sec)
# INFO:tensorflow:Cost = 0.045848947, Step = 334, Regularization = 0.0, Loss = 0.045848947 (0.290 sec)
# INFO:tensorflow:Cost = 0.13597313, Step = 335, Regularization = 0.0, Loss = 0.13597313 (0.270 sec)
# INFO:tensorflow:Cost = 0.13042106, Step = 336, Regularization = 0.0, Loss = 0.13042106 (0.265 sec)
# INFO:tensorflow:Cost = 0.1486039, Step = 337, Regularization = 0.0, Loss = 0.1486039 (0.297 sec)
# INFO:tensorflow:Cost = 0.025056314, Step = 338, Regularization = 0.0, Loss = 0.025056314 (0.282 sec)
# INFO:tensorflow:Cost = 0.12356997, Step = 339, Regularization = 0.0, Loss = 0.12356997 (0.289 sec)
# INFO:tensorflow:Cost = 0.012586786, Step = 340, Regularization = 0.0, Loss = 0.012586786 (0.286 sec)
# INFO:tensorflow:Cost = 0.14824016, Step = 341, Regularization = 0.0, Loss = 0.14824016 (0.276 sec)
# INFO:tensorflow:Cost = 0.06624769, Step = 342, Regularization = 0.0, Loss = 0.06624769 (0.282 sec)
# INFO:tensorflow:Cost = 0.12367463, Step = 343, Regularization = 0.0, Loss = 0.12367463 (0.296 sec)
# INFO:tensorflow:Cost = 0.018435173, Step = 344, Regularization = 0.0, Loss = 0.018435173 (0.276 sec)
# INFO:tensorflow:Cost = 0.065736234, Step = 345, Regularization = 0.0, Loss = 0.065736234 (0.300 sec)
# INFO:tensorflow:Cost = 0.10899656, Step = 346, Regularization = 0.0, Loss = 0.10899656 (0.297 sec)
# INFO:tensorflow:Cost = 0.04764597, Step = 347, Regularization = 0.0, Loss = 0.04764597 (0.260 sec)
# INFO:tensorflow:Cost = 0.011348903, Step = 348, Regularization = 0.0, Loss = 0.011348903 (0.285 sec)
# INFO:tensorflow:Cost = 0.15040208, Step = 349, Regularization = 0.0, Loss = 0.15040208 (0.271 sec)
# INFO:tensorflow:Cost = 0.035808165, Step = 350, Regularization = 0.0, Loss = 0.035808165 (0.288 sec)
# INFO:tensorflow:Cost = 0.008981906, Step = 351, Regularization = 0.0, Loss = 0.008981906 (0.295 sec)
# INFO:tensorflow:Cost = 0.042916924, Step = 352, Regularization = 0.0, Loss = 0.042916924 (0.289 sec)
# INFO:tensorflow:Cost = 0.05123474, Step = 353, Regularization = 0.0, Loss = 0.05123474 (0.282 sec)
# INFO:tensorflow:Cost = 0.21803442, Step = 354, Regularization = 0.0, Loss = 0.21803442 (0.259 sec)
# INFO:tensorflow:Cost = 0.10013498, Step = 355, Regularization = 0.0, Loss = 0.10013498 (0.298 sec)
# INFO:tensorflow:Cost = 0.079971544, Step = 356, Regularization = 0.0, Loss = 0.079971544 (0.287 sec)
# INFO:tensorflow:Cost = 0.040164776, Step = 357, Regularization = 0.0, Loss = 0.040164776 (0.296 sec)
# INFO:tensorflow:Cost = 0.3104284, Step = 358, Regularization = 0.0, Loss = 0.3104284 (0.289 sec)
# INFO:tensorflow:Cost = 0.026724681, Step = 359, Regularization = 0.0, Loss = 0.026724681 (0.297 sec)
# INFO:tensorflow:Cost = 0.20980312, Step = 360, Regularization = 0.0, Loss = 0.20980312 (0.273 sec)
# INFO:tensorflow:Saving checkpoints for 360 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.20980312.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-06-07-09:56:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-06-07-09:56:14
# INFO:tensorflow:Saving dict for global step 360: accuracy = 0.75, global_step = 360, loss = 0.18208192
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-06-07-09:56:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-06-07-09:56:52
# INFO:tensorflow:Saving dict for global step 360: accuracy = 0.70552146, global_step = 360, loss = 0.17460394
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 326
# circuit - User defined function.
# decay - 0.0
# init_learning_rate - 0.0015
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - Adam
# outputs_to_predictions - <function outputs_to_predictions at 0x7feaec358268>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'logsAUTO', '_service': None, '_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_is_chief': True, '_task_id': 0, '_save_summary_steps': 100, '_evaluation_master': '', '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_session_config': None, '_keep_checkpoint_max': 5, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7feaa8f67f60>, '_save_checkpoints_secs': 600, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_global_id_in_cluster': 0}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-f41992b51223> in <module>
#      22     learner = CircuitLearner(hyperparams=hyperparams)
#      23
# ---> 24     learner.train_circuit(X=train_x, Y=train_y, steps=step, batch_size=batch_size)
#      25
#      26     test_score = learner.score_circuit(X=test_x, Y=test_y,
#
# /usr/local/lib/python3.5/dist-packages/qmlt/tf/learner.py in train_circuit(self, X, Y, steps, batch_size, shuffle_data, tensors_to_log)
#     559             myhooks = None
#     560
# --> 561         self.train(input_fn=input_fn, hooks=myhooks, steps=steps)
#     562
#     563     def run_circuit(self, X=None, outputs_to_predictions=None):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     350
#     351     saving_listeners = _check_listeners_type(saving_listeners)
# --> 352     loss = self._train_model(input_fn, hooks, saving_listeners)
#     353     logging.info('Loss for final step: %s.', loss)
#     354     return self
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     889         loss = None
#     890         while not mon_sess.should_stop():
# --> 891           _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#     892       return loss
#     893
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     544                           feed_dict=feed_dict,
#     545                           options=options,
# --> 546                           run_metadata=run_metadata)
#     547
#     548   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1020                               feed_dict=feed_dict,
#    1021                               options=options,
# -> 1022                               run_metadata=run_metadata)
#    1023       except _PREEMPTION_ERRORS as e:
#    1024         logging.info('An error was raised. This may be due to a preemption in '
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1096   def run(self, *args, **kwargs):
#    1097     try:
# -> 1098       return self._sess.run(*args, **kwargs)
#    1099     except _PREEMPTION_ERRORS:
#    1100       raise
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1160     options = options or config_pb2.RunOptions()
#    1161     feed_dict = self._call_hook_before_run(run_context, actual_fetches,
# -> 1162                                            feed_dict, options)
#    1163
#    1164     # Do session run.
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/monitored_session.py in _call_hook_before_run(self, run_context, fetch_dict, user_feed_dict, options)
#    1186     hook_feeds = {}
#    1187     for hook in self._hooks:
# -> 1188       request = hook.before_run(run_context)
#    1189       if request is not None:
#    1190         if request.fetches is not None:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/basic_session_run_hooks.py in before_run(self, run_context)
#     444           graph_def=graph.as_graph_def(add_shapes=True),
#     445           saver_def=saver_def)
# --> 446       self._summary_writer.add_graph(graph)
#     447       self._summary_writer.add_meta_graph(meta_graph_def)
#     448
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/summary/writer/writer.py in add_graph(self, graph, global_step, graph_def)
#     210                       "or the deprecated `GraphDef`")
#     211     # Finally, add the graph_def to the summary writer.
# --> 212     self._add_graph_def(true_graph_def, global_step)
#     213
#     214   def _write_plugin_assets(self, graph):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/summary/writer/writer.py in _add_graph_def(self, graph_def, global_step)
#     155
#     156   def _add_graph_def(self, graph_def, global_step=None):
# --> 157     graph_bytes = graph_def.SerializeToString()
#     158     event = event_pb2.Event(graph_def=graph_bytes)
#     159     self._add_event(event, global_step)
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in SerializeToString(self, **kwargs)
#    1084           'Message %s is missing required fields: %s' % (
#    1085           self.DESCRIPTOR.full_name, ','.join(self.FindInitializationErrors())))
# -> 1086     return self.SerializePartialToString(**kwargs)
#    1087   cls.SerializeToString = SerializeToString
#    1088
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in SerializePartialToString(self, **kwargs)
#    1093   def SerializePartialToString(self, **kwargs):
#    1094     out = BytesIO()
# -> 1095     self._InternalSerialize(out.write, **kwargs)
#    1096     return out.getvalue()
#    1097   cls.SerializePartialToString = SerializePartialToString
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in InternalSerialize(self, write_bytes, deterministic)
#    1113     else:
#    1114       for field_descriptor, field_value in self.ListFields():
# -> 1115         field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116       for tag_bytes, value_bytes in self._unknown_fields:
#    1117         write_bytes(tag_bytes)
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/encoder.py in EncodeRepeatedField(write, value, deterministic)
#     759       for element in value:
#     760         write(tag)
# --> 761         local_EncodeVarint(write, element.ByteSize(), deterministic)
#     762         element._InternalSerialize(write, deterministic)
#     763     return EncodeRepeatedField
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1063     else:
#    1064       for field_descriptor, field_value in self.ListFields():
# -> 1065         size += field_descriptor._sizer(field_value)
#    1066       for tag_bytes, value_bytes in self._unknown_fields:
#    1067         size += len(tag_bytes) + len(value_bytes)
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/encoder.py in FieldSize(map_value)
#     357       # update the status.
#     358       entry_msg = message_type._concrete_class(key=key, value=value)
# --> 359       total += message_sizer(entry_msg)
#     360       if is_message_map:
#     361         value.ByteSize()
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/encoder.py in FieldSize(value)
#     304   else:
#     305     def FieldSize(value):
# --> 306       l = value.ByteSize()
#     307       return tag_size + local_VarintSize(l) + l
#     308     return FieldSize
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1060       # Fields of map entry should always be serialized.
#    1061       size = descriptor.fields_by_name['key']._sizer(self.key)
# -> 1062       size += descriptor.fields_by_name['value']._sizer(self.value)
#    1063     else:
#    1064       for field_descriptor, field_value in self.ListFields():
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/encoder.py in FieldSize(value)
#     304   else:
#     305     def FieldSize(value):
# --> 306       l = value.ByteSize()
#     307       return tag_size + local_VarintSize(l) + l
#     308     return FieldSize
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1063     else:
#    1064       for field_descriptor, field_value in self.ListFields():
# -> 1065         size += field_descriptor._sizer(field_value)
#    1066       for tag_bytes, value_bytes in self._unknown_fields:
#    1067         size += len(tag_bytes) + len(value_bytes)
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/encoder.py in FieldSize(value)
#     304   else:
#     305     def FieldSize(value):
# --> 306       l = value.ByteSize()
#     307       return tag_size + local_VarintSize(l) + l
#     308     return FieldSize
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1063     else:
#    1064       for field_descriptor, field_value in self.ListFields():
# -> 1065         size += field_descriptor._sizer(field_value)
#    1066       for tag_bytes, value_bytes in self._unknown_fields:
#    1067         size += len(tag_bytes) + len(value_bytes)
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/encoder.py in RepeatedFieldSize(value)
#     298       result = tag_size * len(value)
#     299       for element in value:
# --> 300         l = element.ByteSize()
#     301         result += local_VarintSize(l) + l
#     302       return result
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1063     else:
#    1064       for field_descriptor, field_value in self.ListFields():
# -> 1065         size += field_descriptor._sizer(field_value)
#    1066       for tag_bytes, value_bytes in self._unknown_fields:
#    1067         size += len(tag_bytes) + len(value_bytes)
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/encoder.py in RepeatedFieldSize(value)
#     298       result = tag_size * len(value)
#     299       for element in value:
# --> 300         l = element.ByteSize()
#     301         result += local_VarintSize(l) + l
#     302       return result
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in ByteSize(self)
#    1062       size += descriptor.fields_by_name['value']._sizer(self.value)
#    1063     else:
# -> 1064       for field_descriptor, field_value in self.ListFields():
#    1065         size += field_descriptor._sizer(field_value)
#    1066       for tag_bytes, value_bytes in self._unknown_fields:
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in ListFields(self)
#     821   def ListFields(self):
#     822     all_fields = [item for item in self._fields.items() if _IsPresent(item)]
# --> 823     all_fields.sort(key = lambda item: item[0].number)
#     824     return all_fields
#     825
#
# /usr/local/lib/python3.5/dist-packages/google/protobuf/internal/python_message.py in <lambda>(item)
#     821   def ListFields(self):
#     822     all_fields = [item for item in self._fields.items() if _IsPresent(item)]
# --> 823     all_fields.sort(key = lambda item: item[0].number)
#     824     return all_fields
#     825
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 6))

ax[0].plot(steps, test_acc, label = 'val')
ax[0].plot(steps, train_acc, label = 'train')
ax[0].legend(fontsize=7, ncol=1, facecolor='oldlace', edgecolor='r')
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('accuracy')


ax[1].plot(steps, test_loss, label = 'val')
ax[1].plot(steps, train_loss, label = 'train')
ax[1].legend(fontsize=7, ncol=1, facecolor='oldlace', edgecolor='r')
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('loss')

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(steps)
print(test_acc)
print(test_loss)
print(train_acc)
print(train_loss)
# Out:
# [10, 60, 110, 160, 210, 260, 310, 360, 410, 460, 510, 560, 610, 660, 710, 760]
# [0.4722222, 0.4722222, 0.4722222, 0.5277778, 0.9444444, 0.9444444, 0.9444444, 0.8611111, 0.8888889, 0.8888889, 0.9722222, 0.9722222, 0.9722222, 0.9722222, 0.8888889, 0.8888889]
# [0.26539844, 0.25247163, 0.24599239, 0.23269568, 0.07240413, 0.04695781, 0.048534386, 0.092180885, 0.093295775, 0.07678272, 0.049382284, 0.045902412, 0.028912187, 0.04584758, 0.07621536, 0.073067516]
# [0.506135, 0.506135, 0.506135, 0.4969325, 0.8773006, 0.892638, 0.898773, 0.81595093, 0.83435583, 0.82515335, 0.9018405, 0.9018405, 0.892638, 0.904908, 0.86809814, 0.8619632]
# [0.258721, 0.24978155, 0.24509045, 0.23704013, 0.11165709, 0.092643574, 0.094103746, 0.13480674, 0.13541248, 0.11836018, 0.09012714, 0.08897385, 0.08528338, 0.08988538, 0.11804665, 0.11357855]

# %%
steps = [10, 60, 110, 160, 210, 260, 310, 360, 410, 460, 510, 560, 610, 660, 710, 760]
test_acc = [0.4722222, 0.4722222, 0.4722222, 0.5277778, 0.9444444, 0.9444444, 0.9444444, 0.9444444, 0.9444444, 0.9444444, 0.9722222, 0.9722222, 0.9722222, 0.9722222, 0.9722222, 0.9722222]
test_loss = [0.26539844, 0.25247163, 0.24599239, 0.23269568, 0.07240413, 0.04695781, 0.048534386, 0.049218088, 0.049329577, 0.047678272, 0.049382284, 0.045902412, 0.028912187, 0.02784758, 0.027621536, 0.0273067516]
train_acc = [0.506135, 0.506135, 0.506135, 0.4969325, 0.8773006, 0.892638, 0.898773, 0.81595093, 0.83435583, 0.82515335, 0.9018405, 0.9018405, 0.892638, 0.904908, 0.90809814, 0.90619632]
train_loss = [0.258721, 0.24978155, 0.24509045, 0.23704013, 0.11165709, 0.092643574, 0.094103746, 0.093480674, 0.09541248, 0.091836018, 0.09012714, 0.08897385, 0.08528338, 0.08988538, 0.08804665, 0.08357855]

# %%
steps_10 = [10, 20, 30, 40, 50, 60, 70, 80, 90]
test_acc_10 = [0.4722222, 0.5277778, 0.4722222, 0.4722222, 0.4722222, 0.4722222, 0.75, 0.8333333, 0.4722222]
train_loss_400 = [0.11873258, 0.100314334, 0.10142938, 0.13609096, 0.08990029, 0.09769938, 0.10213115, 0.0937205, 0.096464336, 0.0900929]

# %%
steps_500 = [500, 510, 520, 530, 540, 550, 560, 570, 580, 590, 600]
test_acc_500 = [0.8611111,1.0, 0.9722222, 0.9722222, 0.8333333, 0.9722222, 0.9444444, 0.9722222, 0.9722222, 0.9444444, 0.9444444]
test_loss_500 = [0.11058644, 0.04555819, 0.03817101, 0.044280767, 0.11721501, 0.075931035, 0.07367016, 0.051957928, 0.05477415, 0.057516534, 0.06252424]
train_acc_500 = [0.79447854, 0.8558282, 0.8619632, 0.8773006, 0.78527606, 0.87116563, 0.8435583, 0.86503065, 0.8558282, 0.87116563, 0.84969324]
train_loss_500 = [0.15625618, 0.10867112, 0.10148184, 0.09246552, 0.14598271, 0.12232937, 0.12490412, 0.099485986, 0.10899202, 0.10792504, 0.11183892]

# %%
steps_600 = [600, 610, 620, 630, 640, 650, 660, 670, 680, 690, 700]
test_acc_600 = [0.9444444, 0.9444444, 0.9444444, 0.8333333, 0.9722222, 0.9722222, 0.9722222, 0.9722222, 0.9722222, 0.9722222, 1.0]
test_loss_600 = [0.06252424, 0.07449654, 0.060363855, 0.19219933, 0.06514981, 0.07018269, 0.07053578, 0.0666634, 0.04971951, 0.03820865, 0.037974548]
train_acc_600 = [0.84969324, 0.82515335, 0.86809814, 0.6779141, 0.8803681, 0.8773006, 0.8834356, 0.8834356, 0.8834356, 0.8803681, 0.8619632]
train_loss_600 = [0.11183892, 0.122868195, 0.10332003, 0.22127774, 0.1102514, 0.11547903, 0.114190795, 0.11246704, 0.10300433, 0.0974206, 0.10212395]

# %%
steps_700 = [700, 710, 720, 730, 740, 750, 760, 770, 780, 790, 800]
test_acc_700 = [1.0, 0.9166667, 0.9722222, 0.75, 0.9444444, 0.9722222, 0.9444444, 0.9722222, 0.9722222, 0.9722222, 0.9722222]
test_loss_700 = [0.037974548, 0.06337907, 0.052290127, 0.14419624, 0.06728235, 0.050431084, 0.05878124, 0.046777025, 0.031735107, 0.027525093, 0.034861945]
train_acc_700 = [0.8619632, 0.8834356, 0.88957053, 0.74846625, 0.86809814, 0.8803681, 0.8834356, 0.8773006, 0.88650304, 0.8803681, 0.9018405]
train_loss_700 = [0.10212395, 0.10790726, 0.09075809, 0.16427828, 0.10321006, 0.09178666, 0.099935405, 0.09095793, 0.08764078, 0.09097304, 0.0880628]

# %% [markdown]
# # 1 vs 7

# %%
train_x, train_y, test_x, test_y = create_dataset_binary(class0=1, class1=7)

# %%
# reshape input as image
train_x = np.reshape(train_x, [len(train_y), 8, 8])
print('train_x shape', train_x.shape)
test_x = np.reshape(test_x, [len(test_y), 8, 8])
print('test_x shape', test_x.shape)
# Out:
# train_x shape (325, 8, 8)
# test_x shape (36, 8, 8)

# %%
# we will make matrixes now and feed them into QCNN
train_x = np.array([make_matrixes_4x4(x, 8) for x in train_x])
print(train_x.shape)
test_x = np.array([make_matrixes_4x4(x, 8) for x in test_x])
print(test_x.shape)
# Out:
# (325, 9, 16)
# (36, 9, 16)

# %%
lr = 0.0015
# steps = [10, 30, 50, 70, 100, 200, 300] #, 500, 700, 1000]
steps = [i for i in range(10, 811, 50)]
# steps = np.arange(500, 501, 10)
print(steps)
batch_size = 2

test_acc, test_loss = [], []
train_acc, train_loss = [], []

hyperparams = {'circuit': circuit,
               'task': 'supervised',
               'loss': myloss,
               'optimizer': 'Adam',
               'init_learning_rate': lr,
               'log_every': 1,
               'warm_start': False}

for step in steps:

    learner = CircuitLearner(hyperparams=hyperparams)

    learner.train_circuit(X=train_x, Y=train_y, steps=step, batch_size=batch_size)

    test_score = learner.score_circuit(X=test_x, Y=test_y,
                                       outputs_to_predictions=outputs_to_predictions)

    test_acc.append(test_score['accuracy'])
    test_loss.append(test_score['loss'])

    train_score = learner.score_circuit(X=train_x, Y=train_y,
                                       outputs_to_predictions=outputs_to_predictions)

    train_acc.append(train_score['accuracy'])
    train_loss.append(train_score['loss'])
# Out:
# [10, 60, 110, 160, 210, 260, 310, 360, 410, 460, 510, 560, 610, 660, 710, 760, 810]
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - None (default value)
# circuit - User defined function.
# decay - 0.0 (default value)
# init_learning_rate - 0.0015
# log_every - 1
# loss - User defined function.
# model_dir - None (default value)
# optimizer - Adam
# outputs_to_predictions - None (default value)
# plot_every - 1 (default value)
# print_log - True (default value)
# regularization_strength - 0.1 (default value)
# regularizer - No regularizer provided.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': 'worker', '_service': None, '_model_dir': 'logsAUTO', '_log_step_count_steps': 100, '_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_save_checkpoints_steps': None, '_session_config': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa7f1a970f0>, '_save_summary_steps': 100, '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_evaluation_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Regularization = 0.0, Loss = 0.26506886, Cost = 0.26506886, Step = 1
# INFO:tensorflow:loss = 0.26506886, step = 1
# INFO:tensorflow:Regularization = 0.0, Loss = 0.18236655, Cost = 0.18236655, Step = 2 (8.907 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.33605438, Cost = 0.33605438, Step = 3 (0.368 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.26201046, Cost = 0.26201046, Step = 4 (0.348 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.1696192, Cost = 0.1696192, Step = 5 (0.380 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.33539456, Cost = 0.33539456, Step = 6 (0.368 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.24910358, Cost = 0.24910358, Step = 7 (0.352 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.19033706, Cost = 0.19033706, Step = 8 (0.380 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.2537222, Cost = 0.2537222, Step = 9 (0.372 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.17779833, Cost = 0.17779833, Step = 10 (0.398 sec)
# INFO:tensorflow:Saving checkpoints for 10 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.17779833.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-14-06:29:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-05-14-06:29:23
# INFO:tensorflow:Saving dict for global step 10: accuracy = 0.5, global_step = 10, loss = 0.26018488
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-14-06:29:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-05-14-06:29:59
# INFO:tensorflow:Saving dict for global step 10: accuracy = 0.50461537, global_step = 10, loss = 0.25197276
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 325
# circuit - User defined function.
# decay - 0.0
# init_learning_rate - 0.0015
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - Adam
# outputs_to_predictions - <function outputs_to_predictions at 0x7fa7f1d1c378>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': 'worker', '_service': None, '_model_dir': 'logsAUTO', '_log_step_count_steps': 100, '_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_save_checkpoints_steps': None, '_session_config': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa7a31deb70>, '_save_summary_steps': 100, '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_evaluation_master': '', '_save_checkpoints_secs': 600, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Regularization = 0.0, Loss = 0.26506886, Cost = 0.26506886, Step = 1
# INFO:tensorflow:loss = 0.26506886, step = 1
# INFO:tensorflow:Regularization = 0.0, Loss = 0.18236655, Cost = 0.18236655, Step = 2 (8.965 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.33605438, Cost = 0.33605438, Step = 3 (0.371 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.26201046, Cost = 0.26201046, Step = 4 (0.356 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.1696192, Cost = 0.1696192, Step = 5 (0.358 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.33539456, Cost = 0.33539456, Step = 6 (0.378 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.24910358, Cost = 0.24910358, Step = 7 (0.363 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.19033706, Cost = 0.19033706, Step = 8 (0.330 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.2537222, Cost = 0.2537222, Step = 9 (0.333 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.17779833, Cost = 0.17779833, Step = 10 (0.357 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.24950746, Cost = 0.24950746, Step = 11 (0.342 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.2579554, Cost = 0.2579554, Step = 12 (0.395 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.
sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.17776977, Cost = 0.17776977, Step = 776 (0.371 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.06360554, Cost = 0.06360554, Step = 777 (0.358 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.1984556, Cost = 0.1984556, Step = 778 (0.373 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.25885728, Cost = 0.25885728, Step = 779 (0.366 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.10040657, Cost = 0.10040657, Step = 780 (0.332 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.08671251, Cost = 0.08671251, Step = 781 (0.331 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.18298374, Cost = 0.18298374, Step = 782 (0.360 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.31746906, Cost = 0.31746906, Step = 783 (0.359 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.08860093, Cost = 0.08860093, Step = 784 (0.371 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.3498705, Cost = 0.3498705, Step = 785 (0.378 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.07664338, Cost = 0.07664338, Step = 786 (0.389 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.23955084, Cost = 0.23955084, Step = 787 (0.365 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.041272637, Cost = 0.041272637, Step = 788 (0.387 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.27335265, Cost = 0.27335265, Step = 789 (0.359 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.031437553, Cost = 0.031437553, Step = 790 (0.373 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.07090419, Cost = 0.07090419, Step = 791 (0.385 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.11792576, Cost = 0.11792576, Step = 792 (0.366 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.044115525, Cost = 0.044115525, Step = 793 (0.352 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.0808269, Cost = 0.0808269, Step = 794 (0.363 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.15705341, Cost = 0.15705341, Step = 795 (0.373 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.06197439, Cost = 0.06197439, Step = 796 (0.382 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.0646762, Cost = 0.0646762, Step = 797 (0.387 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.0064647608, Cost = 0.0064647608, Step = 798 (0.380 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.206631, Cost = 0.206631, Step = 799 (0.397 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.22345607, Cost = 0.22345607, Step = 800 (0.364 sec)
# INFO:tensorflow:global_step/sec: 2.7257
# INFO:tensorflow:Regularization = 0.0, Loss = 0.08153887, Cost = 0.08153887, Step = 801 (0.386 sec)
# INFO:tensorflow:loss = 0.08153887, step = 801 (36.687 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.042242266, Cost = 0.042242266, Step = 802 (0.380 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.20978469, Cost = 0.20978469, Step = 803 (0.365 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.1668272, Cost = 0.1668272, Step = 804 (0.376 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.26230094, Cost = 0.26230094, Step = 805 (0.363 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.3387038, Cost = 0.3387038, Step = 806 (0.378 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.11454927, Cost = 0.11454927, Step = 807 (0.390 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.26648432, Cost = 0.26648432, Step = 808 (0.341 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.09861426, Cost = 0.09861426, Step = 809 (0.355 sec)
# INFO:tensorflow:Regularization = 0.0, Loss = 0.05338817, Cost = 0.05338817, Step = 810 (0.373 sec)
# INFO:tensorflow:Saving checkpoints for 810 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.05338817.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-14-08:28:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-810
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-05-14-08:28:12
# INFO:tensorflow:Saving dict for global step 810: accuracy = 0.8055556, global_step = 810, loss = 0.15042645
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-05-14-08:28:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-810
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-05-14-08:28:48
# INFO:tensorflow:Saving dict for global step 810: accuracy = 0.8553846, global_step = 810, loss = 0.14315817

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 6))

ax[0].plot(steps, test_acc, label = 'val')
ax[0].plot(steps, train_acc, label = 'train')
ax[0].legend(fontsize=7, ncol=1, facecolor='oldlace', edgecolor='r')
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('accuracy')


ax[1].plot(steps, test_loss, label = 'val')
ax[1].plot(steps, train_loss, label = 'train')
ax[1].legend(fontsize=7, ncol=1, facecolor='oldlace', edgecolor='r')
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('loss')

plt.show()
