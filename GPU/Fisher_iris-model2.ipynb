# %%
import tensorflow as tf
import strawberryfields as sf
import numpy as np
import matplotlib.pyplot as plt

# from strawberryfields import ops
from strawberryfields.ops import Dgate, BSgate, Sgate, Rgate, Pgate

from qmlt.tf import CircuitLearner
from qmlt.tf.helpers import make_param

from sklearn.utils import shuffle
from sklearn import datasets
import numpy as np
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def visualize_dataset(trainX, trainY) -> None:
    fig, axs = plt.subplots(nrows=4, ncols=4)

    colors = ['red', 'blue', 'green']
    test_colors = ['purple', 'black', 'yellow']

    for i in range(4):
        for j in range(4):
            for k in np.unique(trainY, axis=0):
                axs[i % 4, j % 4].plot(trainX[trainY == k, i],
                                       trainX[trainY == k, j],
                                       'o', label='class {}'.format(k), color=colors[k]
                                       )

#                 axs[i % 4, j % 4].plot(testX[testY == k, i],
#                                        testX[testY == k, j],
#                                        'o', label='test_class {}'.format(k), color=test_colors[k]
#                                        )

                axs[i % 4, j % 4].legend(fontsize=5,
                                         ncol=1,
                                         facecolor='oldlace',
                                         edgecolor='r'
                                         )

                # axs[i % 4, j % 4].set_xlim(-1, 10)
                # axs[i % 4, j % 4].set_ylim(-1, 10)

    fig.set_size_inches(10., 6.5)
    plt.show()

# %%
def create_dataset():

    iris = datasets.load_iris()
    x = iris.data
    Y = iris.target
    
    y = Y[np.where(Y != 2)]
    x = x[np.where(Y != 2)]
    
#     print(y)
    
    visualize_dataset(x, y)
    
#     y = []
#     for i in range(len(Y)):
#         if Y[i] == 0:
#             y.append([1., 0., 0.])
#         elif Y[i] == 1:
#             y.append([0., 1., 0.])
#         elif Y[i] == 2:
#             y.append([0., 0., 1.])

    x, y = shuffle(x, np.array(y), random_state=7)
#     x, y = shuffle(x, Y, random_state=7)
    
    sep = round(len(x) * 0.1)
    
    train_x, train_y = x[sep:], y[sep:]
    test_x, test_y = x[:sep], y[:sep]
    
    return train_x, train_y, test_x, test_y

# %%
steps = 700
batch_size = 2


def circuit(X):

    params = [make_param(name='phi'+str(i), constant=.5, monitor=True) for i in range(7)]

    eng, q = sf.Engine(4)
    
    quater_pi = tf.constant(np.pi / 4)

    with eng:
        Sgate(1.5, X[:, 0]) | q[0]
        Sgate(1.5, X[:, 1]) | q[1]
        Sgate(1.5, X[:, 2]) | q[2]
        Sgate(1.5, X[:, 3]) | q[3]
        BSgate(quater_pi, 0) | (q[0], q[1])
        BSgate(quater_pi, 0) | (q[2], q[3])
        Rgate(params[0]) | q[0]
        Rgate(params[1]) | q[1]
        Rgate(params[2]) | q[2]
        BSgate(quater_pi, 0) | (q[1], q[2])
        Rgate(params[3]) | q[1]
        Dgate(params[4]) | q[0]
        Dgate(params[5]) | q[1]
        Dgate(params[6]) | q[2]

    num_inputs = X.get_shape().as_list()[0]
    state = eng.run('tf', cutoff_dim=5, eval=False, batch_size=num_inputs)

    p0 = state.fock_prob([2, 0, 0, 0])
    p1 = state.fock_prob([0, 2, 0, 0])
#     p2 = state.fock_prob([0, 0, 2, 0])
    normalization = p0 + p1 + 1e-10
    circuit_output = p0 / normalization

    return circuit_output


def myloss(circuit_output, targets):
    return tf.losses.mean_squared_error(labels=circuit_output, predictions=targets)
#     return  tf.losses.softmax_cross_entropy(
#                                         logits= circuit_output, 
#                                         onehot_labels=targets
#                                         )


def outputs_to_predictions(output):
    return tf.round(output)
#     print(tf.transpose(output))
#     return tf.one_hot(tf.argmax(output, 1), 3)

# %%
train_x, train_y, test_x, test_y = create_dataset()

# print(train_y)

# %%
hyperparams = {'circuit': circuit,
               'task': 'supervised',
               'loss': myloss,
               'optimizer': 'SGD',
               'init_learning_rate': 0.05,
               'decay': 0.01,
               'print_log': True,
               'log_every': 1,
               'warm_start': False
               }
steps = range(1, 102, 5)
print(steps)

test_acc, test_loss = [], []

for step in steps:

    learner = CircuitLearner(hyperparams=hyperparams)

    learner.train_circuit(X=train_x, Y=train_y, steps=step, batch_size=batch_size)

    test_score = learner.score_circuit(X=test_x, Y=test_y,
                                       outputs_to_predictions=outputs_to_predictions)
    
    test_acc.append(test_score['accuracy'])
    test_loss.append(test_score['loss'] / len(test_y))
# Out:
# range(1, 102, 5)
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - None (default value)
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - None (default value)
# optimizer - SGD
# outputs_to_predictions - None (default value)
# plot_every - 1 (default value)
# print_log - True
# regularization_strength - 0.1 (default value)
# regularizer - No regularizer provided.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f62616b4f28>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Loss for final step: 0.19608608.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-02:56:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-1
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-02:56:54
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.8, global_step = 1, loss = 0.1562171
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6258947080>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.436 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.022 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.46755087, Loss = 0.46755087, Step = 5, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.16986184, Loss = 0.16986184, Step = 6, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Saving checkpoints for 6 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16986184.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-02:57:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-6
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-02:57:16
# INFO:tensorflow:Saving dict for global step 6: accuracy = 0.9, global_step = 6, loss = 0.13058059
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f62608587f0>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.434 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.46755087, Loss = 0.46755087, Step = 5, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.16986184, Loss = 0.16986184, Step = 6, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.13940844, Loss = 0.13940844, Step = 7, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.15893282, Loss = 0.15893282, Step = 8, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.1251842, Loss = 0.1251842, Step = 9, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.05212304, Loss = 0.05212304, Step = 10, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.07356958, Loss = 0.07356958, Step = 11, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Saving checkpoints for 11 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.07356958.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-02:57:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-11
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-02:57:36
# INFO:tensorflow:Saving dict for global step 11: accuracy = 0.9, global_step = 11, loss = 0.11581479
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f62569c9f28>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.431 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.020 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.46755087, Loss = 0.46755087, Step = 5, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.16986184, Loss = 0.16986184, Step = 6, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.13940844, Loss = 0.13940844, Step = 7, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.15893282, Loss = 0.15893282, Step = 8, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.1251842, Loss = 0.1251842, Step = 9, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.05212304, Loss = 0.05212304, Step = 10, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.07356958, Loss = 0.07356958, Step = 11, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.16063303, Loss = 0.16063303, Step = 12, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.20949158, Loss = 0.20949158, Step = 13, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.25538144, Loss = 0.25538144, Step = 14, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.06335775, Loss = 0.06335775, Step = 15, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.04279615, Loss = 0.04279615, Step = 16, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Saving checkpoints for 16 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.04279615.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-02:57:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-16
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-02:57:56
# INFO:tensorflow:Saving dict for global step 16: accuracy = 1.0, global_step = 16, loss = 0.09609978
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6254251198>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.419 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.46755087, Loss = 0.46755087, Step = 5, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.16986184, Loss = 0.16986184, Step = 6, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.13940844, Loss = 0.13940844, Step = 7, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.15893282, Loss = 0.15893282, Step = 8, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.1251842, Loss = 0.1251842, Step = 9, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.05212304, Loss = 0.05212304, Step = 10, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.07356958, Loss = 0.07356958, Step = 11, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.16063303, Loss = 0.16063303, Step = 12, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.20949158, Loss = 0.20949158, Step = 13, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.25538144, Loss = 0.25538144, Step = 14, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.06335775, Loss = 0.06335775, Step = 15, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.04279615, Loss = 0.04279615, Step = 16, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.044389613, Loss = 0.044389613, Step = 17, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.26516277, Loss = 0.26516277, Step = 18, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07307551, Loss = 0.07307551, Step = 19, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.14242731, Loss = 0.14242731, Step = 20, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.21212628, Loss = 0.21212628, Step = 21, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Saving checkpoints for 21 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.21212628.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-02:58:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-21
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-02:58:17
# INFO:tensorflow:Saving dict for global step 21: accuracy = 1.0, global_step = 21, loss = 0.087034345
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6258d077f0>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.435 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.021 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.022 sec)
# INFO:tensorflow:Cost = 0.46755087, Loss = 0.46755087, Step = 5, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.16986184, Loss = 0.16986184, Step = 6, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.13940844, Loss = 0.13940844, Step = 7, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.15893282, Loss = 0.15893282, Step = 8, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.1251842, Loss = 0.1251842, Step = 9, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.05212304, Loss = 0.05212304, Step = 10, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.07356958, Loss = 0.07356958, Step = 11, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.16063303, Loss = 0.16063303, Step = 12, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.20949158, Loss = 0.20949158, Step = 13, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.25538144, Loss = 0.25538144, Step = 14, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.06335775, Loss = 0.06335775, Step = 15, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.04279615, Loss = 0.04279615, Step = 16, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.044389613, Loss = 0.044389613, Step = 17, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.26516277, Loss = 0.26516277, Step = 18, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07307551, Loss = 0.07307551, Step = 19, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.14242731, Loss = 0.14242731, Step = 20, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.21212628, Loss = 0.21212628, Step = 21, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.110240415, Loss = 0.110240415, Step = 22, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.13527983, Loss = 0.13527983, Step = 23, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.049823582, Loss = 0.049823582, Step = 24, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.15705904, Loss = 0.15705904, Step = 25, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.112114914, Loss = 0.112114914, Step = 26, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Saving checkpoints for 26 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.112114914.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-02:58:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-26
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-02:58:37
# INFO:tensorflow:Saving dict for global step 26: accuracy = 1.0, global_step = 26, loss = 0.079621896
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6260b557b8>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.419 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.021 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.46755087, Loss = 0.46755087, Step = 5, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.16986184, Loss = 0.16986184, Step = 6, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.13940844, Loss = 0.13940844, Step = 7, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.15893282, Loss = 0.15893282, Step = 8, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.1251842, Loss = 0.1251842, Step = 9, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.05212304, Loss = 0.05212304, Step = 10, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07356958, Loss = 0.07356958, Step = 11, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.16063303, Loss = 0.16063303, Step = 12, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.20949158, Loss = 0.20949158, Step = 13, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.25538144, Loss = 0.25538144, Step = 14, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.06335775, Loss = 0.06335775, Step = 15, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.04279615, Loss = 0.04279615, Step = 16, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.044389613, Loss = 0.044389613, Step = 17, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.26516277, Loss = 0.26516277, Step = 18, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07307551, Loss = 0.07307551, Step = 19, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.14242731, Loss = 0.14242731, Step = 20, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.21212628, Loss = 0.21212628, Step = 21, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.110240415, Loss = 0.110240415, Step = 22, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.13527983, Loss = 0.13527983, Step = 23, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.049823582, Loss = 0.049823582, Step = 24, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.15705904, Loss = 0.15705904, Step = 25, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.112114914, Loss = 0.112114914, Step = 26, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.085206665, Loss = 0.085206665, Step = 27, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07061409, Loss = 0.07061409, Step = 28, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.124027885, Loss = 0.124027885, Step = 29, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.03755839, Loss = 0.03755839, Step = 30, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.06630296, Loss = 0.06630296, Step = 31, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Saving checkpoints for 31 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.06630296.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-02:58:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-31
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-02:58:58
# INFO:tensorflow:Saving dict for global step 31: accuracy = 1.0, global_step = 31, loss = 0.074118644
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6256bfb6a0>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.419 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.46755087, Loss = 0.46755087, Step = 5, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.16986184, Loss = 0.16986184, Step = 6, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0.13940844, Loss = 0.13940844, Step = 7, Regularization = 0.0 (0.024 sec)
# INFO:tensorflow:Cost = 0.15893282, Loss = 0.15893282, Step = 8, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.1251842, Loss = 0.1251842, Step = 9, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.05212304, Loss = 0.05212304, Step = 10, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07356958, Loss = 0.07356958, Step = 11, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.16063303, Loss = 0.16063303, Step = 12, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.20949158, Loss = 0.20949158, Step = 13, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.25538144, Loss = 0.25538144, Step = 14, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.06335775, Loss = 0.06335775, Step = 15, Regularization = 0.0 (0.028 sec)
# INFO:tensorflow:Cost = 0.04279615, Loss = 0.04279615, Step = 16, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.044389613, Loss = 0.044389613, Step = 17, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.26516277, Loss = 0.26516277, Step = 18, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07307551, Loss = 0.07307551, Step = 19, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.14242731, Loss = 0.14242731, Step = 20, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.21212628, Loss = 0.21212628, Step = 21, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.110240415, Loss = 0.110240415, Step = 22, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.13527983, Loss = 0.13527983, Step = 23, Regularization = 0.0 (0.028 sec)
# INFO:tensorflow:Cost = 0.049823582, Loss = 0.049823582, Step = 24, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0
Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.049823582, Loss = 0.049823582, Step = 24, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.15705904, Loss = 0.15705904, Step = 25, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.112114914, Loss = 0.112114914, Step = 26, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.085206665, Loss = 0.085206665, Step = 27, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07061409, Loss = 0.07061409, Step = 28, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.124027885, Loss = 0.124027885, Step = 29, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.03755839, Loss = 0.03755839, Step = 30, Regularization = 0.0 (0.026 sec)
# ...
# INFO:tensorflow:Cost = 0.08465252, Loss = 0.08465252, Step = 65, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.13810246, Loss = 0.13810246, Step = 66, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.057318296, Loss = 0.057318296, Step = 67, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.10126893, Loss = 0.10126893, Step = 68, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.020213142, Loss = 0.020213142, Step = 69, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.09002192, Loss = 0.09002192, Step = 70, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.07127791, Loss = 0.07127791, Step = 71, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.03114805, Loss = 0.03114805, Step = 72, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.044000357, Loss = 0.044000357, Step = 73, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.08306773, Loss = 0.08306773, Step = 74, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.02321879, Loss = 0.02321879, Step = 75, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.03382158, Loss = 0.03382158, Step = 76, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.01875535, Loss = 0.01875535, Step = 77, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.017338041, Loss = 0.017338041, Step = 78, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.031382307, Loss = 0.031382307, Step = 79, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.019196078, Loss = 0.019196078, Step = 80, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.042595927, Loss = 0.042595927, Step = 81, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.043626823, Loss = 0.043626823, Step = 82, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.09129706, Loss = 0.09129706, Step = 83, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.08144327, Loss = 0.08144327, Step = 84, Regularization = 0.0 (0.025 sec)
# INFO:tensorflow:Cost = 0.023958266, Loss = 0.023958266, Step = 85, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.14586164, Loss = 0.14586164, Step = 86, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.049015537, Loss = 0.049015537, Step = 87, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.05939698, Loss = 0.05939698, Step = 88, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.09224824, Loss = 0.09224824, Step = 89, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.023274632, Loss = 0.023274632, Step = 90, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.046239667, Loss = 0.046239667, Step = 91, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.05898859, Loss = 0.05898859, Step = 92, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.06404918, Loss = 0.06404918, Step = 93, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.029044896, Loss = 0.029044896, Step = 94, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.2232576, Loss = 0.2232576, Step = 95, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.027640251, Loss = 0.027640251, Step = 96, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Saving checkpoints for 96 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.027640251.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-03:03:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-03:03:38
# INFO:tensorflow:Saving dict for global step 96: accuracy = 1.0, global_step = 96, loss = 0.036464423
#
# -----------------------------
#  HYPERPARAMETERS:
#
# batch_size - 10
# circuit - User defined function.
# decay - 0.01
# init_learning_rate - 0.05
# log_every - 1
# loss - User defined function.
# model_dir - logsAUTO
# optimizer - SGD
# outputs_to_predictions - <function outputs_to_predictions at 0x7f6263e109d8>
# plot_every - 1
# print_log - True
# regularization_strength - 0.1
# regularizer - User defined function.
# task - supervised
# warm_start - False
#
#  -----------------------------
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_task_type': 'worker', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f622ca82278>, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_model_dir': 'logsAUTO', '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into logsAUTO/model.ckpt.
# INFO:tensorflow:Cost = 0.19608608, Loss = 0.19608608, Step = 1, Regularization = 0.0
# INFO:tensorflow:step = 1, loss = 0.19608608
# INFO:tensorflow:Cost = 0.20373411, Loss = 0.20373411, Step = 2, Regularization = 0.0 (0.442 sec)
# INFO:tensorflow:Cost = 0.15580036, Loss = 0.15580036, Step = 3, Regularization = 0.0 (0.021 sec)
# INFO:tensorflow:Cost = 0.107134305, Loss = 0.107134305, Step = 4, Regularization = 0.0 (0.023 sec)
# INFO:tensorflow:Cost = 0
Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.10126893, Loss = 0.10126893, Step = 68, Regularization = 0.0 (0.029 sec)
# INFO:tensorflow:Cost = 0.020213142, Loss = 0.020213142, Step = 69, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.09002192, Loss = 0.09002192, Step = 70, Regularization = 0.0 (0.028 sec)
# INFO:tensorflow:Cost = 0.07127791, Loss = 0.07127791, Step = 71, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.03114805, Loss = 0.03114805, Step = 72, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.044000357, Loss = 0.044000357, Step = 73, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.08306773, Loss = 0.08306773, Step = 74, Regularization = 0.0 (0.029 sec)
# INFO:tensorflow:Cost = 0.02321879, Loss = 0.02321879, Step = 75, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.03382158, Loss = 0.03382158, Step = 76, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.01875535, Loss = 0.01875535, Step = 77, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.017338041, Loss = 0.017338041, Step = 78, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.031382307, Loss = 0.031382307, Step = 79, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.019196078, Loss = 0.019196078, Step = 80, Regularization = 0.0 (0.028 sec)
# INFO:tensorflow:Cost = 0.042595927, Loss = 0.042595927, Step = 81, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.043626823, Loss = 0.043626823, Step = 82, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.09129706, Loss = 0.09129706, Step = 83, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.08144327, Loss = 0.08144327, Step = 84, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.023958266, Loss = 0.023958266, Step = 85, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.14586164, Loss = 0.14586164, Step = 86, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.049015537, Loss = 0.049015537, Step = 87, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.05939698, Loss = 0.05939698, Step = 88, Regularization = 0.0 (0.029 sec)
# INFO:tensorflow:Cost = 0.09224824, Loss = 0.09224824, Step = 89, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.023274632, Loss = 0.023274632, Step = 90, Regularization = 0.0 (0.028 sec)
# INFO:tensorflow:Cost = 0.046239667, Loss = 0.046239667, Step = 91, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.05898859, Loss = 0.05898859, Step = 92, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.06404918, Loss = 0.06404918, Step = 93, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.029044896, Loss = 0.029044896, Step = 94, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.2232576, Loss = 0.2232576, Step = 95, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.027640251, Loss = 0.027640251, Step = 96, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:Cost = 0.04085602, Loss = 0.04085602, Step = 97, Regularization = 0.0 (0.028 sec)
# INFO:tensorflow:Cost = 0.03890488, Loss = 0.03890488, Step = 98, Regularization = 0.0 (0.028 sec)
# INFO:tensorflow:Cost = 0.040858302, Loss = 0.040858302, Step = 99, Regularization = 0.0 (0.026 sec)
# INFO:tensorflow:Cost = 0.018065806, Loss = 0.018065806, Step = 100, Regularization = 0.0 (0.027 sec)
# INFO:tensorflow:global_step/sec: 32.4229
# INFO:tensorflow:Cost = 0.0124150645, Loss = 0.0124150645, Step = 101, Regularization = 0.0 (0.032 sec)
# INFO:tensorflow:step = 101, loss = 0.0124150645 (3.087 sec)
# INFO:tensorflow:Saving checkpoints for 101 into logsAUTO/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0124150645.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2023-04-11-03:04:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from logsAUTO/model.ckpt-101
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2023-04-11-03:04:01
# INFO:tensorflow:Saving dict for global step 101: accuracy = 1.0, global_step = 101, loss = 0.0351472

# %%
# lr = 0.05

fig, ax = plt.subplots(ncols=2, figsize=(10, 6))

ax[0].plot(steps, test_acc, color = 'blue', label = 'accuracy')
ax[0].legend(fontsize=7, ncol=1, facecolor='oldlace', edgecolor='r')
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('accuracy')


ax[1].plot(steps, test_loss, color = 'blue', label = 'loss')
# ax[1].plot(steps, cq_val_loss, color = 'red', label = 'val')
ax[1].legend(fontsize=7, ncol=1, facecolor='oldlace', edgecolor='r')
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('loss')

plt.show()

# %%
with open('test_acc.txt', 'r') as file:
    for acc in test_acc:
        file.write(str(acc) + '\n')

# %%
with open('test_loss.txt', 'r') as file:
    for loss in test_loss:
        file.write(str(loss) + '\n')
